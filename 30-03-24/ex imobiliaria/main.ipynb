# %%
print('Inicio do EX. Dados de Imobiliarias')
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_excel('dataframe.xlsx', sheet_name='total por registro')
df.drop(0, inplace=True)
df.columns = df.iloc[0]
df.drop(1, inplace=True)
df.head()
# Out:
# Inicio do EX. Dados de Imobiliarias
# 1 MESORREGIÃO                  NaN Estado de São Paulo (TOTAL)  \
# 2         ANO                  MÊS                    REGISTRO
# 3        2012  2012-01-01 00:00:00                       65055
# 4        2012  2012-02-01 00:00:00                       70510
# 5        2012  2012-03-01 00:00:00                       83103
# 6        2012  2012-04-01 00:00:00                       76915
#
# 1 Metropolitana de São Paulo (TOTAL) Região Metropolitana de São Paulo (RMSP)  \
# 2                           REGISTRO                                 REGISTRO
# 3                              23762                                    21751
# 4                              26162                                    24228
# 5                              31204                                    29367
# 6                              29354                                    26821
#
# 1 Município de São Paulo Demais municípios da RMSP Demais municípios da MSP  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[41], line 2
#       1 # Encontre o índice da linha onde está "REGISTRO"
# ----> 2 indice_registro = df.index[df.iloc[:, 1] == 'REGISTRO'][1]
#       4 # Selecione as linhas abaixo da linha "REGISTRO" até o final do DataFrame
#       5 linhas_de_dados = df.iloc[indice_registro + 1:, :]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:5366, in Index.__getitem__(self, key)
#    5363 if is_integer(key) or is_float(key):
#    5364     # GH#44051 exclude bool, which would return a 2d ndarray
#    5365     key = com.cast_scalar_indexer(key)
# -> 5366     return getitem(key)
#    5368 if isinstance(key, slice):
#    5369     # This case is separated from the conditional above to avoid
#    5370     # pessimization com.is_bool_indexer and ndim checks.
#    5371     return self._getitem_slice(key)
#
# ...
